# %% [markdown]
# # Naive Bayes
#
# NAIVE BAYES is probablisitic based approach in Ml algorithms. Problaisitic appraoch such as decision tree and Random Forest. lets reacall again the in the machine learning we have two categories. The supervised and unsupervised.
#
# First one is the supervised leanring that include -
#
# Linear. SVR SVC, Decision tree, Random forest, Xbgoost, adata boost and gradient bosst.
#
# In classifier -
# log regression, SVC and SVM, DTC, RANDOM forest Classifier, Ada Boost, XG boost, and Gradient Boosting.
#
#
# KNN is another classifier and regression method that we have learning in the supervised learning known as K nearest neightbour.
#
# IN Unsuperivdes we have following -
#
# K means, Hierarchieal CLustering and DB scan.
#
#
#
#
#
# Now NAive Bayes is the supervised learning also classification problems, and is a totally Probability based apporach. Unlike which uses entorhpy and gini index to dertermine purity only of the leaf node.
#
# However Naive bayes completly runs on the prbabiltiy.
#
#
# Prbability - Chance of occuring an event can occur.
#
# Now there are two types of cases in the probability independent and dependent and mutually Exclusive.
#
# Independet Event - Each event does not affect another event.
# Tossing a coin two times. If we get head in first event the probability of getting a head or tail does not change in the second toss or any n number of the toss.
#
# Dependent Event - Two events are dependent on each other, event gets affected by the occurence of another event. The bag with 2red balls or 5 green ones. Picking a green ball and after that probability of any event will change. Lets say probability of picking a green ball next time is different and same goes for the probability of getting a red ball.
#
# same goes in drawing cards consecutively.
#
#
# Mutually Exclusive - The event that you cannot do at the same time. Either this event will hapen or the other one. For example Turning left or right. Once you turn left than u cannot turn right. So such event are mutually exclusive.
#
#
# Diff between Mutually and Independent event.
#
# Mutually exclusive- two event cannot occur at the same time.
#
# Independent event - one event remain unaffected by the occurence of another event. You can get head after getting head first time.
#
#
# SO Now understand the Naive Bayes algorithm. For that we need to understand what dependent and independent probabilities are.
#
# Lets say we have 2 blue ball and 3 red ball.
#
# first event P(A) drawign blue ball 2/5 and then second event P(B) drawing blue ball again = 1/4
#
# so the second event is wriiten as P(B/A) which means prbaiblity of B event happening when A is already happened.
#
#
# Also it is said as P ( A and B) dependent probabilitis.
# the general formula of P(A and B) = P(A) * P(B/A)
#
# So it denotes the probaiblity of the whole consecutive event, which is prbability of event where u will draw a blue ball and then blue ball again.
# ![image.png](attachment:image.png)
#
# SO the we can drive the probaibltiy of P(B/A) = P(A and B) / P(A)
#
#
# Now when we interchange the occurence of events P(B and A) = P(B) * P(A/B)
#
# s prbability of P(A and B) = P (B and A) this two event have equal prbaiblty so we can equate both of the equations.
#
#  P(A) * P(A/B) = P(B) * P(B/A)
#
#  P(B/A) = P(A) * P(A/B)/P(B) ____ Bayes Theroam
#
# so this formula is used in NAive Bayes algortihm to find the probabilty of B event when event A is already happened.
#
# Now understand how the machine learning model is made with naive bayes which uses the probabilistic approach.
#
# P(B/A) = P(A) * P(A/B)/P(B) ____ Bayes Theroam
#
#
# dataset
#
# X1, X2, X3, X4, X5.......... ------ Data set
# so let takes we need y outcome
# so will use naive bayes formula to calculate the prbability of y event occuring given X1, X2, X3, X4, X5..........
#
#
# P(Y/X1, X2, X3, X4, X5..) = P(y)* P(X1, X2, X3, X4, X5..XN/Y)/P(X1, X2, X3, X4, X5....)
#
# which can be written as
#                        =P(Y) * P(X1/Y) * P(X2/Y)* P(X3/Y)...* P(Xn/Y)/P(X1)* P(X2) * P(X3)...* P(Xn)
#
# we can also say it as p(class/data) = p(data/class) * p(class)/p(data)
#
#
# Let understand with the example o/p is binary output yes no manner.
#
#
#     X1     X2     X3    O/P
#
#                         Yes
#
#                         No
#
# p(yes/x1,x2,x3) = p(y)* p(x1/yes) * p(x2/yes) * p(x3/yes)/ p(x1) * p(x2) * p(x3)
#
#
#
# p(no/x1,x2,x3) = p(no)* p(x1/no) * p(x2/no) * p(x3/no)/ p(x1) * p(x2) * p(x3)
#
#
# lets assume p(yes/x1,x2,x3) = 0.13
#
#             p(no/x1,x2,x3) = 0.05
#
#
#    0.13/0.13+0.05 = 0.13/0.18 = 72%
#
#    0.05/0.13+0.05 = 0.05/0.18 = 28%
#
#    p(y/xi) > p(n/xi)
#
#    to we will choose yes probability of yes given x1,x2,x,3 is true is greater than probability of no given x1,x2,x3.
#
#
# Naive bayes is classifier it cannot solve regrssion problems. Since it uses the simple approach of probability to classify class.
